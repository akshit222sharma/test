# %%
import pandas as pd
import numpy as np

# %%
data= pd.read_csv('sample_email.csv',encoding='ISO-8859-1')

# %%
data
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
data.head()
# Out:
#   first_name last_name            company_name               address  \
# 0      James      Butt       Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 3      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 4    Donette    Foller     Printing Dimensions          34 Center St
#
#           city      county state    zip        phone1         phone  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# 3    Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# 4     Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                            email  \
# 0              jbutt@luminate.ai
# 1  josephine_darakjy@luminate.ai
# 2                art@luminate.ai
# ...

# %%
f1=data['Email Boby']
f2= f1.iloc[:1 :]
file= pd.DataFrame(f2)
file
# Out:
#                                           Email Boby
# 0  I have a nearly unreadable font in my Warehous...

# %%
data1= data.iloc[:, [0,1,8,9,10,11,12]]
data1.head()
# Out:
#   first_name last_name        phone1         phone  \
# 0      James      Butt  504-621-8927  504-845-1427
# 1  Josephine   Darakjy  810-292-9388  810-374-9840
# 2        Art    Venere  856-636-8749  856-264-4130
# 3      Lenna  Paprocki  907-385-4412  907-921-2010
# 4    Donette    Foller  513-570-1893  513-549-4561
#
#                            email  \
# 0              jbutt@luminate.ai
# 1  josephine_darakjy@luminate.ai
# 2                art@luminate.ai
# 3          lpaprocki@luminate.ai
# 4     donette.foller@luminate.ai
#
#                                              subject  \
# 0  When EMVX creation comes the message "The crea...
# 1   It falters when processing highly segmented p...
# 2         Cwvemx files falter in Sales firstclass 20
# 3   When creating EM / EMVX with Windows 7, it ma...
# 4   Drivers for the USB Process Manager could not...
#
#                                           Email Boby
# 0  I have a nearly unreadable font in my Warehous...
# ...

# %%
names1= data1['first_name']
names2= data1['last_name']
names= (names1+' '+names2)
email = data1['email']


email_syntex= data1['Email Boby']


email_subject= data1['subject']
phone1= data1['phone1']
phone= data1['phone']
#print("Hi "+  names + "     " +  email + email_syntex + email_subject)
try1= print('Email to: '+ email + " \n Subject Line: "+ email_subject + '\n Hi'+ names+',' + email_syntex+ '.Please do contact me at'
            +phone1 +'Please do contact me at '+phone+ 'Thanks,\nRob Willson')

def file(email,email_subject,names,email_syntex,phone1,phone):
    show='Email to: '+ email + " \n Subject Line: "+ email_subject + '\n Hi'+ names+',' + email_syntex+ '.Please do contact me at'+phone1 +'Please do contact me at '+phone+ 'Thanks,\nRob Willson'
    return(show)

print(file(email,email_subject,names,email_syntex,phone1,phone))
# Out:
# 0     Email to: jbutt@luminate.ai \n Subject Line: W...
# 1     Email to: josephine_darakjy@luminate.ai \n Sub...
# 2     Email to: art@luminate.ai \n Subject Line:  Cw...
# 3     Email to: lpaprocki@luminate.ai \n Subject Lin...
# 4     Email to: donette.foller@luminate.ai \n Subjec...
# 5     Email to: simona@luminate.ai \n Subject Line: ...
# 6     Email to: mitsue_tollner@luminate.ai \n Subjec...
# 7     Email to: leota@luminate.ai \n Subject Line:  ...
# 8     Email to: sage_wieser@luminate.ai \n Subject L...
# 9     Email to: kris@luminate.ai \n Subject Line:  T...
# 10    Email to: minna_amigon@luminate.ai \n Subject ...
# 11    Email to: amaclead@luminate.ai \n Subject Line...
# 12    Email to: kiley.caldarera@luminate.ai \n Subje...
# 13    Email to: gruta@luminate.ai \n Subject Line:  ...
# 14    Email to: calbares@luminate.ai \n Subject Line...
# 15    Email to: mattie@luminate.ai \n Subject Line: ...
# 16    Email to: meaghan@luminate.ai \n Subject Line:...
# ...

# %%
def file2(email,email_subject,names,email_syntex,phone1,phone):
    show= 'Email to: '+ email
    show1=print(show +" \n Subject Line: "+ email_subject)
    show2=print(show1, '\n Hi'+ names+',')
    show3= print(show2, email_syntex)
    show4=print(show3, '.Please do contact me at'+phone1)
    show5=print(show4, 'Please do contact me at '+phone)
    show6= print(show5,'Thanks,\nRob Willson')
    return(show6)
        
submit= print(file2(email,email_subject,names,email_syntex,phone1,phone))
# Out:
# 0     Email to: jbutt@luminate.ai \n Subject Line: W...
# 1     Email to: josephine_darakjy@luminate.ai \n Sub...
# 2     Email to: art@luminate.ai \n Subject Line:  Cw...
# 3     Email to: lpaprocki@luminate.ai \n Subject Lin...
# 4     Email to: donette.foller@luminate.ai \n Subjec...
# 5     Email to: simona@luminate.ai \n Subject Line: ...
# 6     Email to: mitsue_tollner@luminate.ai \n Subjec...
# 7     Email to: leota@luminate.ai \n Subject Line:  ...
# 8     Email to: sage_wieser@luminate.ai \n Subject L...
# 9     Email to: kris@luminate.ai \n Subject Line:  T...
# 10    Email to: minna_amigon@luminate.ai \n Subject ...
# 11    Email to: amaclead@luminate.ai \n Subject Line...
# 12    Email to: kiley.caldarera@luminate.ai \n Subje...
# 13    Email to: gruta@luminate.ai \n Subject Line:  ...
# 14    Email to: calbares@luminate.ai \n Subject Line...
# 15    Email to: mattie@luminate.ai \n Subject Line: ...
# 16    Email to: meaghan@luminate.ai \n Subject Line:...
# ...

# %%
prediction_file= tibble(Id= submit)
write_csv(prediction_file, 'submission.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-934cb970d217> in <module>
# ----> 1 prediction_file= tibble(Id= submit)
#       2 write_csv(prediction_file, 'submission.csv')
#
# NameError: name 'tibble' is not defined

# %%
phone1= data1['phone1']==(504-621-8927)
phone1
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# Name: phone1, dtype: bool
